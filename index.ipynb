# %% [markdown]
# <img src='OUTILS/bandeau_MF.png' align='right' width='100%'/>

# %% [markdown]
# <div style='background: linear-gradient(135deg, #1a5276 0%, #2e86c1 100%); color: white; padding: 20px; border-radius: 15px; text-align: center; margin-bottom: 20px;'>
# <h1 style='margin: 0;'>🛰️ Manipulation des données satellitaires</h1>
# </br>
# <p style='margin: 5px 0 0 0; font-size: 1.1em;'>TRAVAUX PRATIQUES - Météo-France</p>
# </div>
#
# <div style='display: flex; justify-content: space-between; background-color: #f8f9fa; padding: 15px; border-radius: 10px; margin: 10px 0;'>
#     <div><strong>👤 Rudy Coste</strong> <span style='color: #6c757d;'>(Météo-France)</span></div>
# </div>
# <div style='display: flex; justify-content: space-between; background-color: #f8f9fa; padding: 15px; border-radius: 10px; margin: 10px 0;'>
#     <div><strong>👤 Jean-Baptiste Hernandez</strong> <span style='color: #6c757d;'>(Météo-France)</span></div></br>
#     <div><strong>👤 Olivier Membrive</strong> <span style='color: #6c757d;'>(Météo-France)</span></div></br>
# </div>
#
# <div style='text-align: right; margin: 10px 0;'>
#     <a href="./DOCS/programme_formation_s.pdf" target="_blank" style='text-decoration: none;'>
#         <span style='background-color: #2e86c1; color: white; padding: 8px 15px; border-radius: 20px; font-size: 0.9em;'>
#             📅 Voir le calendrier
#         </span>
#     </a>
# </div>
#
# ---
#
# <div style='background-color: #eaf2f8; padding: 15px; border-radius: 10px; border-left: 5px solid #2e86c1;'>
# <h2 style='margin-top: 0;'>🎯 Objectifs de la formation</h2>
#
# ## Compétence
# ###  1️⃣  Découvrir les outils et applicatifs nécessaires
# ###  2️⃣  Utiliser des données géoréférencées (**NetCDF & TIFF**)
# ###  3️⃣  Produire des images **monocanal**, **compositions colorées**, **sandwich**
# ###  4️⃣  Extraire des données par **point de grille**
# ###  5️⃣  Effectuer des **reprojections** & **découpes** de domaines
# ###  6️⃣  Ajouter des titres, légendes, frontières...
# ###  7️⃣  Télécharger des données avec EUMDAC
# ###  8️⃣  Exécuter des **scripts** bash et python
# </div>
#
# > 💡 *L'ensemble des documents et fichiers restera téléchargeable & disponible pour une réutilisation ultérieure*
#
# <a id='TOC-TOP'></a>

# %% [markdown]
# <div style='background-color: #f39c12; color: white; padding: 12px; border-radius: 8px; margin: 20px 0 15px 0;'>
# <h1 id='section1' style='margin: 0;'>📖 Introduction</h1>
# </div>

# %% [markdown]
# <h2 style='color: #1a5276;'>💡 Pourquoi manipuler les données satellitaires ?</h2>
#
# <div style='display: grid; grid-template-columns: 1fr 1fr; gap: 15px; margin: 15px 0;'>
#     <div style='background-color: #f0f8ff; padding: 15px; border-radius: 10px; border-left: 4px solid #2e86c1;'>
#         <h4 style='margin-top: 0;'>🧠 Comprendre</h4>
#         <p style='margin: 0;'>Les mécanismes et les étapes de production d'une image satellite</p>
#     </div>
#     <div style='background-color: #f0fff0; padding: 15px; border-radius: 10px; border-left: 4px solid #28b463;'>
#         <h4 style='margin-top: 0;'>✨ Créer</h4>
#         <p style='margin: 0;'>De nouveaux produits adaptés à vos besoins spécifiques</p>
#     </div>
#     <div style='background-color: #fff8f0; padding: 15px; border-radius: 10px; border-left: 4px solid #f39c12;'>
#         <h4 style='margin-top: 0;'>🔄 Reproduire</h4>
#         <p style='margin: 0;'>Des données anciennes à partir des archives NetCDF</p>
#     </div>
#     <div style='background-color: #f0f0ff; padding: 15px; border-radius: 10px; border-left: 4px solid #8e44ad;'>
#         <h4 style='margin-top: 0;'>🤖 Automatiser</h4>
#         <p style='margin: 0;'>Des productions automatiques (images & animations)</p>
#     </div>
#     <div style='background-color: #fff0f0; padding: 15px; border-radius: 10px; border-left: 4px solid #e74c3c;'>
#         <h4 style='margin-top: 0;'>🎛️ Adapter</h4>
#         <p style='margin: 0;'>Les réglages des produits à une région / une saison</p>
#     </div>
#     <div style='background-color: #f0fff8; padding: 15px; border-radius: 10px; border-left: 4px solid #1abc9c;'>
#         <h4 style='margin-top: 0;'>📐 Haute résolution</h4>
#         <p style='margin: 0;'>Créer des images haute résolution personnalisées</p>
#     </div>
# </div>
#
# ---
#
# <div style='background-color: #fef9e7; padding: 15px; border-radius: 10px; border: 1px solid #f1c40f;'>
# <h4 style='margin-top: 0; color: #7d6608;'>📡 Niveau 1 - Données brutes</h4>
# <p style='margin: 0;'>Les données de niveau 1 sont des données satellitaires ayant bénéficié de corrections des erreurs instrumentales ou géométriques de base. Les signaux du satellite (radiance) sont convertis notamment en réflectance et températures de brillance, <strong>sans correction atmosphérique complète</strong>.</p>
# </div>

# %% [markdown]
# <div style='background-color: #2980b9; color: white; padding: 12px; border-radius: 8px; margin: 20px 0 15px 0;'>
# <h1 id='section1' style='margin: 0;'>1️⃣ Présentations</h1>
# </div>

# %% [markdown]
# <div style='background-color: #d4e6f1; padding: 12px; border-radius: 8px; margin: 10px 0;'>
# <h3 id='section1' style='margin: 0;'>🛠️ 1.1. Présentation des outils pour les TP</h3>
# </div>
#
# <div style='display: flex; flex-wrap: wrap; gap: 15px; margin: 15px 0;'>
#     <div style='flex: 1; min-width: 200px; background-color: #f8f9fa; padding: 15px; border-radius: 10px; text-align: center;'>
#         <a href="./DOCS/presentation_outils.pdf" target="_blank" style='text-decoration: none;'>
#             <div style='font-size: 2.5em;'>📚</div>
#             <div style='font-weight: bold; color: #2c3e50;'>GitLab, JupyterLab,<br>Conda, GDAL, PyTROLL</div>
#             <div style='color: #2e86c1; font-size: 0.9em;'>📄 PDF</div>
#         </a>
#     </div>
#     <div style='flex: 1; min-width: 200px; background-color: #f8f9fa; padding: 15px; border-radius: 10px; text-align: center;'>
#         <a href="./DOCS/presentation_jupyter_notebook.pdf" target="_blank" style='text-decoration: none;'>
#             <div style='font-size: 2.5em;'>📓</div>
#             <div style='font-weight: bold; color: #2c3e50;'>Jupyter Notebook</div>
#             <div style='color: #2e86c1; font-size: 0.9em;'>📄 PDF</div>
#         </a>
#     </div>
#     <div style='flex: 1; min-width: 200px; background-color: #f8f9fa; padding: 15px; border-radius: 10px; text-align: center;'>
#         <a href="./DOCS/presentation_gitlab_github.pdf" target="_blank" style='text-decoration: none;'>
#             <div style='font-size: 2.5em;'>🐙</div>
#             <div style='font-weight: bold; color: #2c3e50;'>Git, GitLab & GitHub</div>
#             <div style='color: #2e86c1; font-size: 0.9em;'>📄 PDF</div>
#         </a>
#     </div>
#     <div style='flex: 1; min-width: 200px; background-color: #f8f9fa; padding: 15px; border-radius: 10px; text-align: center;'>
#         <a href="./DOCS/mtg_fci_chunk.pdf" target="_blank" style='text-decoration: none;'>
#             <div style='font-size: 2.5em;'>🧩</div>
#             <div style='font-weight: bold; color: #2c3e50;'>MTG FCI Chunks</div>
#             <div style='color: #2e86c1; font-size: 0.9em;'>📄 PDF</div>
#         </a>
#     </div>
#     <div style='flex: 1; min-width: 200px; background-color: #f8f9fa; padding: 15px; border-radius: 10px; text-align: center;'>
#         <a href="./DOCS/TP_manipulation_donnee_sat_mise_en_place.pdf" target="_blank" style='text-decoration: none;'>
#             <div style='font-size: 2.5em;'>🚀</div>
#             <div style='font-weight: bold; color: #2c3e50;'>Mise en place</div>
#             <div style='color: #2e86c1; font-size: 0.9em;'>📄 PDF</div>
#         </a>
#     </div>
# </div>
#
#
# <div style='background-color: #d4e6f1; padding: 12px; border-radius: 8px; margin: 10px 0;'>
# <h3 id='section1' style='margin: 0;'>🛠️ 1.2. Présentations</h3>
# </div>
#
# <div style='display: flex; flex-wrap: wrap; gap: 15px; margin: 15px 0;'>
#     <div style='flex: 1; min-width: 200px; background-color: #f8f9fa; padding: 15px; border-radius: 10px; text-align: center;'>
#     <a href="./DOCS/production_CMS.pdf" target="_blank" style='text-decoration: none;'>
#         <div style='font-size: 2.5em;'>🧩</div>
#         <div style='font-weight: bold; color: #2c3e50;'>Production CMS</div>
#         <div style='color: #2e86c1; font-size: 0.9em;'>📄 PDF</div>
#     </a>
#     </div>
#     <div style='flex: 1; min-width: 200px; background-color: #f8f9fa; padding: 15px; border-radius: 10px; text-align: center;'>
#         <a href="./DOCS/differents_fichiers_sources_satellitaires.pdf" target="_blank" style='text-decoration: none;'>
#             <div style='font-size: 2.5em;'>📚</div>
#             <div style='font-weight: bold; color: #2c3e50;'>Données satellitaires: principaux fichiers sources</div>
#             <div style='color: #2e86c1; font-size: 0.9em;'>📄 PDF</div>
#         </a>
#     </div>
#     <div style='flex: 1; min-width: 200px; background-color: #f8f9fa; padding: 15px; border-radius: 10px; text-align: center;'>
#         <a href="./DOCS/Principes_imagerie_RGB_LD.pdf" target="_blank" style='text-decoration: none;'>
#             <div style='font-size: 2.5em;'>🧩</div>
#             <div style='font-weight: bold; color: #2c3e50;'>Principes imagerie RGB</div>
#             <div style='color: #2e86c1; font-size: 0.9em;'>📄 PDF</div>
#         </a>
#     </div>
#     <div style='flex: 1; min-width: 200px; background-color: #f8f9fa; padding: 15px; border-radius: 10px; text-align: center;'>
#         <a href="./DOCS/GeoColorRGB_etapes_production.pdf" target="_blank" style='text-decoration: none;'>
#             <div style='font-size: 2.5em;'>🎨</div>
#             <div style='font-weight: bold; color: #2c3e50;'>Principales étapes de production d'un produit Geocolor RGB</div>
#             <div style='color: #2e86c1; font-size: 0.9em;'>📄 PDF</div>
#         </a>
#     </div>
# </div>

# %% [markdown]
# <div style='background-color: #27ae60; color: white; padding: 12px; border-radius: 8px; margin: 20px 0 15px 0;'>
# <h1 id='section1' style='margin: 0;'>2️⃣ Utilisation des Jupyter Notebook</h1>
# </div>
#
# <div style='background-color: #fdf2e9; padding: 15px; border-radius: 10px; border-left: 5px solid #e67e22; margin: 10px 0;'>
# <h4 style='margin-top: 0;'>📋 PRÉREQUIS</h4>
# <p style='margin: 0;'>Un répertoire <code>/stockage/DATA</code> est accessible depuis votre compte avec des données sources</p>
# </div>
#
# <div style='background-color: #eaf2f8; padding: 15px; border-radius: 10px; border-left: 5px solid #2e86c1; margin: 15px 0;'>
# <h3 style='margin-top: 0;'>📓 Découverte de Jupyter Notebook</h3>
# <p><a href="./NOTEBOOK/a_decouvrir_jupyter-notebook.ipynb" target="_blank" style='font-size: 1.1em; font-weight: bold;'>A - Premier pas avec Jupyter Notebook →</a></p>
# <p style='color: #6c757d; font-size: 0.9em;'>Découverte de l'environnement Jupyter et des commandes de base</p>
# </div>

# %% [markdown]
# <h3 style='color: #1a5276; margin-top: 25px;'>🖼️ Découverte d'une image TIFF</h3>
#
# <div style='background-color: #f0f8ff; padding: 15px; border-radius: 10px; border-left: 4px solid #2e86c1; margin: 10px 0;'>
# <h4 style='margin-top: 0;'>B1 - Manipulation de données satellitaires - Format TIFF</h4>
# <p><a href="./NOTEBOOK/b1_manipulation_TIF_GEOCOLOR-RGB_MF.ipynb" target="_blank">🔗 Notebook B1 - Production Météo-France</a></p>
# <ul style='margin: 5px 0;'>
#     <li>Utilisation d'un fichier <strong>TIFF</strong></li>
#     <li>Manipulation avec <strong>GDAL</strong> d'une image <strong>RGB</strong></li>
#     <li><strong>Reprojections</strong> diverses, ajout de couches</li>
# </ul>
# </div>
#
# <div style='background-color: #f0f8ff; padding: 15px; border-radius: 10px; border-left: 4px solid #2e86c1; margin: 10px 0;'>
# <h4 style='margin-top: 0;'>B2 - Manipulation de données satellitaires - Format TIFF</h4>
# <p><a href="./NOTEBOOK/b2_manipulation_TIF_GEOCOLOR-RGB_eumetview.ipynb" target="_blank">🔗 Notebook B2 - Production Eumetview</a></p>
# <ul style='margin: 5px 0;'>
#     <li>Utilisation d'un fichier <strong>TIFF</strong></li>
#     <li>Manipulation avec <strong>GDAL</strong> d'une image <strong>RGB</strong></li>
#     <li><strong>Reprojections</strong> diverses, ajout de couches</li>
# </ul>
# </div>

# %% [markdown]
# <h3 style='color: #1a5276; margin-top: 25px;'>🌐 Découverte & utilisation d'un NetCDF</h3>
#
# <div style='background-color: #f0f8ff; padding: 15px; border-radius: 10px; border-left: 4px solid #2e86c1; margin: 10px 0;'>
# <h4 style='margin-top: 0;'>C1 - Manipulation de données satellitaires - Production Météo-France</h4>
# <p><a href="./NOTEBOOK/c1_manipulation_NetCDF_VIS_IR_MF.ipynb" target="_blank">🔗 Notebook C1 - Données Météo-France</a></p>
# <ul style='margin: 5px 0;'>
#     <li>Analyser un fichier <strong>NetCDF</strong></li>
#     <li>Produire une image à partir d'un canal Visible ou IR</li>
#     <li>Modifier la dynamique des valeurs</li>
#     <li><strong>Extraction</strong> d'une valeur ponctuelle</li>
# </ul>
# </div>
#
# <div style='background-color: #f0f8ff; padding: 15px; border-radius: 10px; border-left: 4px solid #27ae60; margin: 10px 0;'>
# <h4 style='margin-top: 0;'>C2 - Manipulation de données satellitaires - Données EUMETSAT</h4>
# <p><a href="./NOTEBOOK/c2_manipulation_NetCDF_VIS_IR_Eumetsat.ipynb" target="_blank">🔗 Notebook C2 - Données EUMETSAT</a></p>
# <ul style='margin: 5px 0;'>
#     <li>Analyser un fichier <strong>NetCDF</strong></li>
#     <li>Produire une image à partir d'un canal Visible ou IR</li>
#     <li>Modifier la dynamique des valeurs</li>
# </ul>
# </div>
#
# <div style='background-color: #f0f8ff; padding: 15px; border-radius: 10px; border-left: 4px solid #e74c3c; margin: 10px 0;'>
# <h4 style='margin-top: 0;'>D - Manipulation de données SST - Format NetCDF</h4>
# <p><a href="./NOTEBOOK/d_manipulation_NetCDF_SST.ipynb" target="_blank">🔗 Notebook D - Température de Surface</a></p>
# <ul style='margin: 5px 0;'>
#     <li>Analyser un fichier <strong>NetCDF</strong></li>
#     <li>Produire une image de <strong>SST</strong></li>
#     <li>Appliquer une palette et modifier la dynamique des valeurs</li>
#     <li><strong>Reprojections</strong> diverses de planisphères</li>
# </ul>
# </div>
#
# <h3 style='color: #1a5276; margin-top: 25px;'>🎨 Utilisation de plusieurs canaux d'un NetCDF</h3>
#
# <div style='background-color: #f0f8ff; padding: 15px; border-radius: 10px; border-left: 4px solid #8e44ad; margin: 10px 0;'>
# <h4 style='margin-top: 0;'>E - MTG GDAL Multicanaux</h4>
# <p><a href="./NOTEBOOK/e_MTG_gdal_multicanaux.ipynb" target="_blank">🔗 Notebook E - Multicanaux</a></p>
# <ul style='margin: 5px 0;'>
#     <li>Utilisation d'un fichier <strong>netcdf</strong> multicanaux MTG (<strong>Multic</strong>)</li>
#     <li>Production avec <strong>GDAL</strong> d'une image <strong>RGB</strong></li>
#     <li>Production d'une image RGB (<strong>Cloud Type RGB</strong>)</li>
#     <li><strong>Reprojections</strong> diverses</li>
# </ul>
# </div>
#
# <div style='background-color: #f0f8ff; padding: 15px; border-radius: 10px; border-left: 4px solid #d35400; margin: 10px 0;'>
# <h4 style='margin-top: 0;'>F - MTG GDAL Multicanaux Opérations</h4>
# <p><a href="./NOTEBOOK/f_MTG_gdal_Mmulti_MF.ipynb" target="_blank">🔗 Notebook F - Opérations</a></p>
# <ul style='margin: 5px 0;'>
#     <li>Utilisation d'un <strong>netcdf</strong> multicanaux MTG (<strong>Multic</strong>)</li>
#     <li><strong>Opérations</strong> avec <strong>GDAL</strong> sur les bandes (<strong>calculs</strong> et <strong>Gamma</strong>)</li>
#     <li>Production d'une image RGB (<strong>Dust RGB</strong>)</li>
# </ul>
# </div>
#
# <h3 style='color: #1a5276; margin-top: 25px;'>🔄 Images sandwich et pansharpening</h3>
#
# <div style='background-color: #f0f8ff; padding: 15px; border-radius: 10px; border-left: 4px solid #1abc9c; margin: 10px 0;'>
# <h4 style='margin-top: 0;'>G - Images sandwich et pansharpening</h4>
# <p><a href="./NOTEBOOK/g_manipulation_TIF_sandwich_et_pansharpening.ipynb" target="_blank">🔗 Notebook G - Sandwich & Pansharpening</a></p>
# <ul style='margin: 5px 0;'>
#     <li>Utilisation de fichiers <strong>netcdf</strong> et <strong>tiffs</strong></li>
#     <li>Fusion, sandwich, et <strong>pansharpening</strong></li>
# </ul>
# </div>
#
# <h3 style='color: #1a5276; margin-top: 25px;'>🐍 Satpy</h3>
#
# <div style='background-color: #f0f8ff; padding: 15px; border-radius: 10px; border-left: 4px solid #e67e22; margin: 10px 0;'>
# <h4 style='margin-top: 0;'>H - Satpy : Découverte et utilisation</h4>
# <p><a href="./NOTEBOOK/h_MTG_satpy_chunk_geocolor.ipynb" target="_blank">🔗 Notebook H - Satpy</a></p>
# <ul style='margin: 5px 0;'>
#     <li>Qu'est-ce que <strong>Satpy</strong></li>
#     <li>Utilisation des <strong>chunks</strong> (Fichiers segmentés MTG)</li>
#     <li>Production d'une image composite avec <strong>Satpy</strong></li>
#     <li>Ajout des frontières avec <strong>GDAL</strong></li>
# </ul>
# </div>
#
# <div style='background-color: #f0f8ff; padding: 15px; border-radius: 10px; border-left: 4px solid #2980b9; margin: 10px 0;'>
# <h4 style='margin-top: 0;'>I - Satpy : Notebook pour exercice</h4>
# <p><a href="./NOTEBOOK/i_MTG_satpy_chunk_autre.ipynb" target="_blank">🔗 Notebook I - Exercice Satpy</a></p>
# <ul style='margin: 5px 0;'>
#     <li>Production d'une image composite avec <strong>Satpy</strong></li>
# </ul>
# </div>
#
# <h3 style='color: #1a5276; margin-top: 25px;'>☁️ Téléchargement de données sur un cloud</h3>
#
# <div style='background-color: #f0f8ff; padding: 15px; border-radius: 10px; border-left: 4px solid #2c3e50; margin: 10px 0;'>
# <h4 style='margin-top: 0;'>J - EUMDAC : Téléchargement de données MTG</h4>
# <p><a href="./NOTEBOOK/j_eumdac.ipynb" target="_blank">🔗 Notebook J - EUMDAC</a></p>
# <ul style='margin: 5px 0;'>
#     <li>Installer l'<strong>EUMETSAT Data Access Client</strong> (EUMDAC)</li>
#     <li>Télécharger des données MTG (chunks, tif)</li>
#     <li>Visualiser ces données</li>
#     <li>Utilisation du <strong>Data Tailor</strong></li>
# </ul>
# </div>
#
# <h3 style='color: #1a5276; margin-top: 25px;'>🛰️ MSG (Meteosat Second Generation)</h3>
#
# <div style='background-color: #f0f8ff; padding: 15px; border-radius: 10px; border-left: 4px solid #16a085; margin: 10px 0;'>
# <h4 style='margin-top: 0;'>L - Manipulations GDAL sur MSG</h4>
# <p><a href="./NOTEBOOK/l_MSG_manipulation_gdal_geotiff.ipynb" target="_blank">🔗 Notebook L - MSG GDAL</a></p>
# <ul style='margin: 5px 0;'>
#     <li>Utilisation d'un fichier <strong>Netcdf MSG</strong></li>
#     <li>Manipulation avec <strong>GDAL</strong> (projection, transparence, graticule, logo...)</li>
# </ul>
# </div>
#
# <div style='background-color: #f0f8ff; padding: 15px; border-radius: 10px; border-left: 4px solid #c0392b; margin: 10px 0;'>
# <h4 style='margin-top: 0;'>M - MSG avec Satpy</h4>
# <p><a href="./NOTEBOOK/m_MSG_satpy_nat.ipynb" target="_blank">🔗 Notebook M - MSG Satpy</a></p>
# <ul style='margin: 5px 0;'>
#     <li>Utilisation d'un fichier <strong>Nat</strong> (Fichier natif MSG)</li>
#     <li>Manipulation avec <strong>Satpy</strong></li>
#     <li>Production d'une image <strong>Sandwich</strong></li>
# </ul>
# </div>

# %% [markdown]
# <div style='background-color: #8e44ad; color: white; padding: 12px; border-radius: 8px; margin: 20px 0 15px 0;'>
# <h1 id='section1' style='margin: 0;'>📜 Scripts</h1>
# </div>
#
# <div style='background-color: #f5eef8; padding: 15px; border-radius: 10px; border-left: 4px solid #8e44ad; margin: 10px 0;'>
# <h4 style='margin-top: 0;'>Script de création d'une image composite avec Satpy</h4>
# <p><a href="./SCRIPTS/exemple_script_composite_satpy.py" target="_blank">🔗 Voir le script</a></p>
# <ul style='margin: 5px 0;'>
#     <li>Utilisation des <strong>chunks</strong> (Fichiers segmentés MTG)</li>
#     <li>Production d'une image composite avec <strong>Satpy</strong></li>
#     <li>À exécuter dans un <strong>terminal</strong> avec l'environnement <code>env_MF_teledetection</code></li>
# </ul>
# </div>
#
# <div style='background-color: #f5eef8; padding: 15px; border-radius: 10px; border-left: 4px solid #2980b9; margin: 10px 0;'>
# <h4 style='margin-top: 0;'>Script de création d'une image avec Satpy</h4>
# <p><a href="./SCRIPTS/faire_telechargement_et_composites.sh" target="_blank">🔗 Voir le script</a></p>
# <ul style='margin: 5px 0;'>
#     <li>Téléchargement des <strong>chunks</strong> (Fichiers segmentés MTG)</li>
#     <li>Production d'une image avec Satpy + Pyresample + Xarray + Numpy + Matplotlib + GDAL + Pillow</li>
#     <li>À exécuter dans un <strong>terminal</strong> avec l'environnement <code>env_MF_teledetection</code></li>
# </ul>
# </div>
#
# <div style='background-color: #f5eef8; padding: 15px; border-radius: 10px; border-left: 4px solid #27ae60; margin: 10px 0;'>
# <h4 style='margin-top: 0;'>Script de création d'une image Sandwich</h4>
# <p><a href="./SCRIPTS/faire_telechargement_et_sandwich.sh" target="_blank">🔗 Voir le script</a></p>
# <ul style='margin: 5px 0;'>
#     <li>Utilisation des <strong>chunks</strong> (Fichiers segmentés MTG)</li>
#     <li>Production d'une image avec Satpy + Pyresample + Xarray + Numpy + Matplotlib + GDAL + Pillow</li>
#     <li>À exécuter dans un <strong>terminal</strong> avec l'environnement <code>env_MF_teledetection</code></li>
# </ul>
# </div>

# %% [markdown]
# <div style='background-color: #d35400; color: white; padding: 12px; border-radius: 8px; margin: 20px 0 15px 0;'>
# <h1 id='section1' style='margin: 0;'>🎁 Bonus</h1>
# </div>
#
# <div style='background-color: #fdedec; padding: 15px; border-radius: 10px; border-left: 4px solid #e74c3c; margin: 10px 0;'>
# <h4 style='margin-top: 0;'>🔍 Voir à travers une RGB</h4>
# <p><a href="http://jupyter.fr-mf-general.s.ewcloud.host/galerie/loupes.html" target="_blank">🌐 Accéder à la galerie CMS</a></p>
# <ul style='margin: 5px 0;'>
#     <li>Accéder à un site web du CMS présentant quelques produits avec outils de visualisation</li>
#     <li>Comprendre la composition d'une RGB : outil <strong>"Loupe RGB"</strong> dans <code>DOCS/OUTILS-MTG</code></li>
# </ul>
# </div>
#
# <div style='background-color: #fef9e7; padding: 15px; border-radius: 10px; border: 1px solid #f1c40f; margin: 10px 0;'>
# <h4 style='margin-top: 0;'>📂 Fichiers sources</h4>
# <p>Un répertoire <code>MF_DATA</code> est présent sur votre home contenant les fichiers sources</p>
# </div>

# %% [markdown]
# <div style='background-color: #2c3e50; color: white; padding: 12px; border-radius: 8px; margin: 20px 0 15px 0;'>
# <h1 id='section1' style='margin: 0;'>3️⃣ Divers</h1>
# </div>
#
# <div style='background-color: #f8f9fa; padding: 15px; border-radius: 10px; border: 1px solid #dee2e6; margin: 10px 0;'>
# <h4 style='margin-top: 0; color: #2c3e50;'>📖 Recette RGB</h4>
# <p><a href="./DOCS/RGB-WS-2025_MeetingReport_final.pdf" target="_blank">📄 RGB Workshop 2025 - Meeting Report</a></p>
# <p style='color: #6c757d; font-size: 0.9em;'>Documentation sur les compositions RGB et leurs applications</p>
# </div>
#
# ---
#
# <div style='text-align: center; padding: 20px; background: linear-gradient(135deg, #1a5276, #2e86c1); color: white; border-radius: 10px;'>
# <p style='margin: 0;'>📧 Pour toute question : <a href='mailto:meteo-spatiale@meteo.fr' style='color: #f1c40f;'>meteo-spatiale@meteo.fr</a></p>
# <p style='margin: 5px 0 0 0; font-size: 0.8em; opacity: 0.8;'>Tous les noms de produits, logos et marques sont la propriété de leurs propriétaires respectifs.</p>
# </div>
