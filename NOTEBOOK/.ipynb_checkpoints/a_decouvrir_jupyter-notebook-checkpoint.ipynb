# %% [markdown]
# <img src='../OUTILS/bandeau_MF.png' align='right' width='100%'/>

# %% [markdown]
# # <div style='background-color: #27ae60; color: white; padding: 20px; border-radius: 10px; text-align: center;'> 📓 Découvrir Jupyter Notebook</div>
#
# ---

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# ⚠️ <b>PRÉREQUIS</b>
#
# Ce Notebook ne nécessite pas de prérequis.
# Consulter la <a href="../DOCS/presentation_jupyter_notebook.pdf" target="_blank">présentation générale Jupyter</a> si besoin.
#
# </div>
# <hr>

# %% [markdown]
# <div class="alert alert-info" role="alert">
#
# 💡 <b>Jupyter permet d’avoir au même endroit, au travers d'une seule interface web :</b>
#
#  - 📝 les commentaires (Markdown) ;
#  - 💻 le code : commandes bash, Python, HTML, imports de librairies... ;
#  - 📊 les données : fichiers sources satellitaires, fonds de carte, frontières... ;
#  - 🖼️ la visualisation des données.
#
# </div>

# %% [markdown]
#
# ### 🧩 2 Types de cellules
#
# Deux formats principaux pour chaque cellule :
#
# - **Markdown** : pour afficher du texte, des images, des formules, des tableaux.
# - **Code** : pour insérer du code (Python, Bash, etc.) et voir son exécution.
#
# > 💡 *Pour changer le type : sélectionnez la cellule puis utilisez le menu déroulant dans la barre d'outils.*

# %% [markdown]
# ### 🚀 3 Exécuter une cellule et passer à la suivante
#
# Cliquez sur une cellule, puis utilisez **`Shift + Entrée`** (ou le bouton **▶️** dans la barre d'outils). Le résultat s'affiche directement sous la cellule.

# %% [markdown]
# **Exemple :** exécutez la cellule ci-dessous pour afficher le répertoire courant.

# %%
cd ~/MF_DATA_MANIPULATION
# Out:
# /home/coster/MF_DATA_MANIPULATION

# %%
pwd
# Out:
# '/home/coster/MF_DATA_MANIPULATION'

# %% [markdown]
# > ℹ️ *Le numéro entre crochets `[1]` s'incrémente à chaque exécution de cellule de code.*

# %% [markdown]
# ### ✏️ 4 Gérer les cellules
#
# #### ➕ Ajouter une cellule
# Cliquez sur une cellule, puis sur le symbole **`+`** dans la barre qui apparaît à droite.
#
# #### 🔁 Déplacer ou copier une cellule
# Utilisez les flèches (⬆️ ⬇️) pour déplacer, ou l'icône **copier** (deux feuilles).
#
# #### 🗑️ Supprimer une cellule
# Cliquez sur la poubelle 🗑️.
#
# #### ↩️ Annuler une action
# `Ctrl + Z` (dans la cellule active).

# %% [markdown]
#
# ### ⚙️ 5 Sélection du kernel
#
# Le **kernel** est le moteur d'exécution du code (Python, etc.).
#
# 👉 En haut à droite de la page, sélectionnez le kernel **`env_MF_teledetection`**, qui contient tous les exécutables nécessaires pour les TP.

# %% [markdown]
#
# ### 🔄 6 Redémarrer le kernel
#
# Si vous souhaitez réinitialiser l'environnement (effacer toutes les variables, relancer le code depuis le début), cliquez sur le bouton **⟳** (restart kernel) dans la barre d'outils.

# %% [markdown]
#
# ### 🖥️ 7 Terminal intégré
#
# Jupyter permet d'ouvrir un terminal directement dans l'interface :
#
# 1. Cliquez sur **+** (nouvel onglet).
# 2. Sélectionnez **Terminal**.
# 3. Vous pouvez glisser/déposer le terminal pour le placer où vous voulez.

# %% [markdown]
#
# ### 📥 8 Récupération des éléments pour le stage
#
# Si ce n'est pas déjà fait, **ouvrez un terminal** et lancez la commande suivante sous votre `home` :
#
# ```bash
# git clone https://github.com/MF-VDS/MF_DATA_MANIPULATION.git
# ```
#
# Cela téléchargera tous les notebooks, données et outils nécessaires.
#
#
# ---
#
# ✅ **Fin du notebook** – Vous êtes prêt à manipuler des données satellites ! 🛰️
