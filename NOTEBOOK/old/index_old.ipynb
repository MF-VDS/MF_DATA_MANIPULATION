# %% [markdown]
# <img src='OUTILS/bandeau_MF.png' align='right' width='100%'/>

# %% [markdown]
# <div class="alert alert-info alert-success">
# <h1>Manipulation des données satellitaires </h1></div>
# </br>
#
# Rudy Coste (Météo-France)</br>
# Jean-Baptiste Hernandez (Météo-France)</br>
# Olivier Membrive (Météo-France)</br>
#  </img><a href="./DOCS/programme_formation_manipulation_donnees_satellitaires.pdf" target="_blank">  <p> <img src='./OUTILS/calendar.png' alt='git' width='17px'>  Rappel calendrier </p></a>
# </div>
#
#
# # TRAVAUX PRATIQUES
# ## Contenus :
# ## - Découvrir les outils et applicatifs nécessaires ;
# ## - Utilisation de données géoréférencées (**NetCDF & TIFF**) ;
# ## - Production d'images **monocanal**, **compositions colorée**, **sandwich** ;
# ## - Extraction de données par **point de grille** ;
# ## - **Reprojections** & **découpes** de domaines ;
# ## - Ajouts de titres, légendes, frontières... ;
# ## - Télécharger des données avec Eumdac ;
# ## - Execution de **scripts** bash et python ;
#
# ## <em> L'ensemble des documents et fichiers restera téléchargeable & disponible pour une réutilisation ultérieure </em>
#
# <a id='TOC-TOP'></a>
#
# </br></br>

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# # <a id='section1'></a>Introduction
# </div>

# %% [markdown]
# # Apports de la manipulation de données ?

# %% [markdown]
# ### <img src='./OUTILS/idea.png' alt='git' width='22px'> Comprendre les mécanismes et les étapes de production d'une image ;

# %% [markdown]
# ### <img src='./OUTILS/idea.png' alt='git' width='22px'> Créer des nouveaux produits ;

# %% [markdown]
# ### <img src='./OUTILS/history.png' alt='git' width='20px'> Reproduire des données anciennes à partir des netcdf  ;

# %% [markdown]
# ### <img src='./OUTILS/prod.png' alt='git' width='21px'> Mettre en place des productions automatiques (images & animations) ;

# %% [markdown]
# ###  <img src='./OUTILS/tune.png' alt='git' width='17px'> Modifier des réglages de produits afin de les adapter à une région / une saison.

# %% [markdown]
# ### <img src='./OUTILS/tune.png' alt='git' width='17px'> Créer des images hautes résolutions.

# %% [markdown]
# Les données de niveau 1 sont des données satellitaires ayant bénéficiées de correction des erreurs instrumentales ou géométriques de base. Les signaux du satellite (radiance) sont convertis notamment en reflectance et températures de brillance, sans correction atmosphérique complète.

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# # <a id='section1'></a>1. Présentations
# </div>

# %% [markdown]
# <div class="alert alert-info" role="alert">
#
# ## <a id='section1'></a>&emsp; 1.1. Présentations des différents outils pour les TP
# </div>

# %% [markdown]
# ## &emsp; <a href="./DOCS/presentation_outils.pdf" target="_blank">  <img src='./OUTILS/icon_pdf.png' alt='git' width='20px'> Présentation générale de GitLab, JupyterLab, Conda, GDAL, PyTROLL</a>

# %% [markdown]
# ## <a id='section1'></a>&emsp;&emsp;   Jupyter Notebook

# %% [markdown]
# ## &emsp;&emsp;&emsp;<a href="DOCS/presentation_jupyter_notebook.pdf" target="_blank"><img src='./OUTILS/jnb.png' alt='git' width='30px'>  Présentation générale jupyter</a>

# %% [markdown]
# ## <a id='section1'></a>&emsp;&emsp;   Git, GitLab et GitHub

# %% [markdown]
# ## &emsp;&emsp;&emsp; <a href="./DOCS/presentation_gitlab_github.pdf" target="_blank">  <img src='./OUTILS/git.png' alt='git' width='20px'> Présentation générale git</a>

# %% [markdown]
# <div class="alert alert-info" role="alert">
#
# ## <a id='section1'></a>&emsp; 1.2 Imagerie Satellitaire,formats MTG
# </div>

# %% [markdown]
# ## &emsp;<a href="DOCS/mtg_fci_chunk.pdf" target="_blank">  Éléments mtg fci chunks</a>

# %% [markdown]
# <div class="alert alert-info" role="alert">
#
# ## <a id='section1'></a>&emsp; 1.3. Mise en place
# </div>

# %% [markdown]
# ## &emsp;<a href="DOCS/TP_manipulation_donnee_sat_mise_en_place.pdf" target="_blank">  Description de la mise en place</a>

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# # <a id='section1'></a>2. Utilisation des Jupyter Notebook
#
# </div>

# %% [markdown]
#
# <b>**PREREQUIS** </b>
#
# Un répertoire "/stockage/DATA" est accessible depuis votre compte avec des données sources

# %% [markdown]
# **Jupyter Notebook**:
#
# **</img><a href="./NOTEBOOK/a_decouvrir_jupyter-notebook.ipynb" target="_blank">A - 1er pas jupyter notebook</a>**</br>
#
# ## Découverte d'une image TIFF
#
# **<a href="./NOTEBOOK/b_manipulation_TIF_GEOCOLOR-RGB_MF.ipynb" target="_blank">B - Manipulation de données satellitaires Production Météo-France - Format TIFF </a>**</br>
# &ensp; Utilisation d'un fichier **TIFF** ;</br>
# &ensp; Manipulation avec **GDAL** d'une **image RGB** ;</br>
# &ensp; **Reprojections** diverses, ajout de couches.
#
# **<a href="./NOTEBOOK/b_manipulation_TIF_GEOCOLOR-RGB_MF.ipynb" target="_blank">B - Manipulation de données satellitaires Production Eumetsat - Format TIFF </a>**</br>
# &ensp; Utilisation d'un fichier **TIFF** ;</br>
# &ensp; Manipulation avec **GDAL** d'une **image RGB** ;</br>
# &ensp; **Reprojections** diverses, ajout de couches.
#
# ## Découverte & utilisation d'un NetCDF
#
# **<a href="./NOTEBOOK/c_manipulation_NetCDF_VIS_IR.ipynb" target="_blank">C - 🌍🛰️ Manipulation de données satellitaires - Production Météo-France - Format NetCDF</a>**</br>
# &ensp; Analyser un fichier **NetCDF** ;</br>
# &ensp; Produire une image à partir d'un canal Visible ou IR ;</br>
# &ensp; Modifier la dynamique des valeurs ;</br>
# &ensp; **Extraction**  d'une valeur ponctuelle.
#
# **<a href="./NOTEBOOK/c_manipulation_NetCDF_VIS_IR_Eumetsat.ipynb" target="_blank">C - 🌍🛰️ Manipulation de données satellitaires - Données Eumetsat - Format NetCDF</a>**</br>
# &ensp; Analyser un fichier **NetCDF** ;</br>
# &ensp; Produire une image à partir d'un canal Visible ou IR ;</br>
# &ensp; Modifier la dynamique des valeurs ;</br>
#
# **<a href="./NOTEBOOK/d_manipulation_NetCDF_SST.ipynb" target="_blank">D - 🌍🛰️ Manipulation de données satellitaires - Format NetCDF</a>**</br>
# &ensp; Analyser un fichier **NetCDF** ;</br>
# &ensp; Produire une image de SST ;</br>
# &ensp; Appliquer une palette et modifier la dynamique des valeurs ;</br>
# &ensp; **Reprojections** diverses de planisphères.
#
# ## Utilisation de plusieurs canaux d'un NetCDF
#
# **<a href="./NOTEBOOK/e_MTG_gdal_multicanaux.ipynb" target="_blank">E - 🌍🛰️ MTG_gdal_multicanaux-netcdf</a>**</br>
# &ensp; Utilisation d'un fichier **netcdf**  (Fichier multicanaux MTG **Multic**) ;</br>
# &ensp; Production avec **GDAL** d'une image RGB ;</br>
# &ensp; Production d'une image RGB (Cloud Type RGB) ;
# &ensp; **Reprojections** diverses.
#
# **<a href="./NOTEBOOK/f_MTG_gdal_Mmulti_MF.ipynb" target="_blank">F - 🌍🛰️ MTG_gdal_multicanaux_operations-netcdf</a>**</br>
# &ensp; Utilisation d'un **netcdf** (Fichier multicanaux MTG **Multic**);</br>
# &ensp; **Opérations** avec **GDAL** sur les bandes, (**calculs** et **Gamma**);</br>
# &ensp; Production d'une image RGB (Dust RGB).
#
# ## Images sandwich et pansharpening
#
# **<a href="./NOTEBOOK/g_manipulation_TIF_sandwich_et_pansharpening.ipynb" target="_blank">G - 🌍🛰️ Images sandwich et pansharpening</a>**</br>
# &ensp; Utilisation de fichiers **netcdf** et **tiffs** ;</br>
# &ensp; Fusion, sandwich, et pansharpening ;</br>
#
# ## Satpy
#
# **<a href="./NOTEBOOK/h_MTG_satpy_chunk_geocolor.ipynb" target="_blank">H - 🌍🛰️Satpy : découverte et utilisation </a>**</br>
# &ensp; Qu'est ce que Satpy ;</br>
# &ensp; Utilisation des  **chunks** (Fichiers segmentés MTG ) ;</br>
# &ensp; Production d'une image composite avec **Satpy** ;</br>
# &ensp; Ajout des frontières avec **GDAL**
#
# **<a href="./NOTEBOOK/i_MTG_satpy_chunk_autre.ipynb" target="_blank">I - 🌍🛰️Satpy : Notebook pour exercice </a>**</br>
# &ensp; Production d'une image composite avec **Satpy**</br>
#
#
# ## Téléchargement de données sur un cloud
#
# **<a href="./NOTEBOOK/j_eumdac.ipynb" target="_blank"> J - 🌍🛰️ Eumdac : téléchargement de données MTG depuis l'eumdac, et visualisation</a>**</br>
# &ensp; Installer l'**EUMETSAT Data Access Client** (EUMDAC);</br>
# &ensp; Télécharger des données MTG (chunks, tif);</br>
# &ensp; Visualiser ces données
# &ensp; Utilisation du Data Tailor
#
# ## MSG
#
# **</img><a href="./NOTEBOOK/l_MSG_manipulation_gdal_geotiff.ipynb" target="_blank"> 🌍🛰️ Manipulations Gdal</a>**</br>
# &ensp; Utilisation d'un fichier **Netcdf MSG** ;</br>
# &ensp; Manipulation du fichier avec **Gdal** (projection, transparence, graticule, logo...);</br>
#
# **</img><a href="./NOTEBOOK/m_MSG_satpy_nat.ipynb" target="_blank">🌍🛰️ MSG_satpy_nat</a>**</br>
# &ensp; utilisation d'un fichier **Nat** (Fichier natif MSG);</br>
# &ensp; manipulation du fichier avec **satpy**;</br>
# &ensp; production d'une image;</br>
# &ensp; production d'une image "Sandwich".

# %% [markdown]
# ## Scripts :
#
# **<a href="./SCRIPTS/exemple_script_composite_satpy.py" target="_blank"> Script de création d'une image composite avec Satpy</a>**</br>
# &ensp; utilisation des  **chunks** (Fichiers segmentés MTG );</br>
# &ensp; production d'une image composite avec **satpy**;</br>
# &ensp; > à executer dans un  **terminal** avec l'environnement conda env_MF_teledetection
#
# **<a href="./SCRIPTS/faire_telechargement_et_composites.sh" target="_blank"> Script de création d'une image avec Satpy</a>**</br>
# &ensp; téléchargement des  **chunks** (Fichiers segmentés MTG );</br>
# &ensp; utilisation des  **chunks** (Fichiers segmentés MTG );</br>
# &ensp; production d'une image avec la suite Satpy + Pyresample + Xarray + Numpy + Matplotlib + GDAL + Pillow ;</br>
# &ensp; > à executer dans un  **terminal** avec l'environnement conda env_MF_teledetection
#
# **<a href="./SCRIPTS/faire_telechargement_et_sandwich.sh" target="_blank"> Script de création d'une image Sandwich</a>**</br>
# &ensp; utilisation des  **chunks** (Fichiers segmentés MTG );</br>
# &ensp; production d'une image avec la suite Satpy + Pyresample + Xarray + Numpy + Matplotlib + GDAL + Pillow ;</br>
# &ensp; > à executer dans un  **terminal** avec l'environnement conda env_MF_teledetection

# %% [markdown]
# **</img><a href="http://jupyter.fr-mf-general.s.ewcloud.host/galerie/loupes.html" target="_blank"> Bonus : voir à travers une RGB</a>**</br>
# &ensp; Accéder à un site web du CMS de présentation de quelques produits, accompagné de quelques outils de visualisation. Site hébergé sur l'EWC;</br>
# &ensp; Comprendre de quoi est constituer une RGB : outil "Loupe RGB" dans DOCS/OUTILS-MTG

# %% [markdown]
# Un répertoire MF_DATA est présent sur votre home contenant les fichiers sources

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# # <a id='section1'></a>3. Divers
#
# </div>

# %% [markdown]
# ### Recette RGB

# %% [markdown]
#
# <img src='./OUTILS/icon_pdf.png' alt='icon pdf' width='30px'></img><a href="./DOCS/RGB-WS-2025_MeetingReport_final.pdf" target="_blank"> RGB Workshop 2025</a>
